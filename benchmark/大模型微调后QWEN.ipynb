# %% [markdown]
# ### 启动Qwen
# ```
# API_PORT=8002 llamafactory-cli api examples/inference/llama3_lora_sft_qwen_finetune_noprompt.yaml
# API_PORT=8002 llamafactory-cli api examples/inference/llama3_lora_sft_qwen_finetune_myprompt.yaml
# API_PORT=8002 llamafactory-cli api examples/inference/llama3_lora_sft_qwen_finetune_schemaprompt.yaml
# API_PORT=8002 llamafactory-cli api examples/inference/llama3_lora_sft_qwen_finetune_vectorprompt.yaml
# ```

# %%
model = "QWEN"
import requests
## 启动微调过后的模型 接口形式为openai API_PORT=8000 llamafactory-cli api examples/inference/llama3_lora_sft.yaml
url = "http://0.0.0.0:8002/v1/chat/completions"  # 替换为目标URL
data = {
    "model": "string",
    "stream":False,
    "messages": [
        {
            "role": "user",
            "content": ""
        },
    ]
}

# %%
## no prompt
import json
key_values1 = None
no_prompt_notrain_val = []
with open("/data/liuytest/数据处理/中医药/train_data_no_prompt_test.json", 'r',encoding="utf-8") as json_file:
    key_values1 = json.load(json_file)
    for kv in key_values1:
        print(kv['instruction'])
        print(kv['output'])
        data['messages'][0]['content'] = "请将以下自然语言翻译为对该数据库的Cypher查询:\n"+kv['instruction']

        response = requests.post(url, json=data, timeout=600)
        json_data = response.json()
        # print(json_data)
        json_data =  json_data["choices"][0]["message"]["content"]
        print(json_data)
        no_prompt_notrain_val.append({"label":kv['output'],"predict":json_data})

with open(f"zyy_train_data_no_prompt_train_test_{model}.json", 'w',encoding="utf-8") as json_file:
    json.dump(no_prompt_notrain_val, json_file ,ensure_ascii=False,indent=4)
# Out:
# 能详细说说当归补血丸的特点吗？
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# 能否介绍一下风湿镇痛丸的作用？类似功效的药品又有哪些呢？
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 )-[r:作用功效]->(m {name: '风湿镇痛丸'} ) return  m,m[r]
# 哪些药品具有温中散寒的效果？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品) return n;
# 我想了解三核九翼的15个不同类别，能给我相关数据吗？
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# 请阐述一下风湿镇痛丸药品的疗效，并给出其他具有相似疗效的药品名字。
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:药品 { name: '风湿镇痛丸' }) RETURN n.character;
# 请阐述一下银黄颗粒药品的功效，另外，有哪些其他药品也有类似的功能？
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' }) return n.character;
# 能告诉我七珍丸的禁忌是什么吗？
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# 请问清胃黄连片的包装规格是多少？
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# MATCH (n:药品 { name: '清胃黄连片' }) RETURN n.specifications;
# 请阐述一下越鞠保和丸的药品功效，另外请列举一些具有相似功效的药品名
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m) RETURN m;
# 你知道哪些药物能除湿止痛吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品) return n;
# 你知道国公酒主要由哪些药材组成吗？
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品) RETURN n
# 八宝坤顺丸有什么独特之处或功效？
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# 使用上清丸需要注意什么禁忌？
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# 能否提供21条关于中国系列的分类信息？
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# 请给我34条三核九翼的不同类型数据
# match (n:三核九翼) return n limit 34;
# MATCH (n:三核九翼) RETURN n limit 34;
# 能否分享20条关于药材的详细数据？
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# 对于嘈杂不适，你有什么药品可以推荐的吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品)-[r:适应症]->(m:症状 { name: '嘈杂不适' }) return n;
# 药品中哪些会用到吴茱萸作为配方？
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '吴茱萸'} ) return n;
# 能否告知消炎解毒丸的禁忌和注意事项
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# 你知道小儿和胃丸是由哪些药材组成的吗？
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品)-[r:主要成分]->(m) return m;
# 我想获取21条中国系列的分类样本，可以提供吗？
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# 你能提供仙茸壮阳口服液的主要特性吗？
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# 请提供一些养阴清肺膏的主要特点信息。
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# 三核九翼有哪些细分的分类
# match (n:三核九翼) return n;
# MATCH (n:三核九翼) RETURN n;
# 在哪些药品制作中会用到黄柏(盐炒)
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '黄柏(盐炒)'}) RETURN n;
# 能告诉我养阴清肺膏怎么用吗？
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.use;
# 能温中散寒的药品都有哪些呢？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品) return n;
# 能否给我提供17条关于中国系列的分类信息？
# match (n:中国系列) return n limit 17;
# MATCH (n:中国系列) RETURN n limit 17;
# 在处理持久的咳嗽和百日咳时，有哪些药品推荐？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# MATCH (n:药品) RETURN n MATCH (n {name: '百日咳清热颗粒'} )-[r:作用功效]->(m) RETURN m MATCH (m)<-[r2:作用功效]-(m1) RETURN m1
# 你能列举一下中国系列的细分分类吗？
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# 请问你能给我提供21条药品数据吗？
# match (n:药品) return n limit 21;
# MATCH (n:药品) RETURN n limit 21;
# 查找节点中name属性值为六味地黄丸的节点对应的id
#  match (n{name:'六味地黄丸'}) return id(n)
# MATCH (n:药品) WHERE n.name = '六味地黄丸' RETURN n;
# 哪些药品中可以使用石决明？
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '石决明'} ) RETURN  n;
# 舟车丸有哪些禁忌？
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# 使用消食退热糖浆需要注意什么禁忌？
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# 对于长期咳嗽和百日咳，有什么药品可以建议？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# MATCH (n:药品) WHERE n.name IN ['长期咳嗽', '百日咳'] RETURN n;
# 能用什么作为烹饪的辅料？
# MATCH (n:辅料) RETURN n;
# MATCH (n:辅料) RETURN n;
# 详细介绍一下脏连丸的信息可以吗？
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 请问包含哪些药品？
# match (n:药品) return n;
# MATCH (n:药品) RETURN n;
# 配方里使用了哪些药材？
# match (n:药材) return n;
# match (n:药品)-[r:配方]->(m) return m;
# 在制药中，豆蔻(去壳)有哪些用途？
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# MATCH (n:药品)-[r:用途]->(m {name: '豆蔻(去壳)'}) RETURN n;
# 请给我37条辅料的相关数据
# match (n:辅料) return n limit 37;
# MATCH (n:辅料) RETURN n limit 37;
# 哪些药品可以使用栀子(姜炙)？
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return n;
# 数据库里存了多少种药？
# match (n:药材 ) return count(*);
# MATCH (n:药品) RETURN COUNT(n)
# 能列举一些具有消炎退热效果的药品吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品) return n;
# 请说明消炎解毒丸的禁用情况
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# MATCH (n:药品 { name: '消炎解毒丸' }) RETURN n.taboo;
# 能给我提供20条药材的信息吗?
# match (n:药材) return n limit 20;
# MATCH (n:药材) RETURN n limit 20;
# 有什么材料可以作为辅料呢？
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# 定位到节点，其name属性是六味地黄丸，返回该节点的id
#  match (n{name:'六味地黄丸'}) return id(n)
# MATCH (n:药品 { name: '六味地黄丸' }) RETURN n;
# 小儿健身片针对哪些症状有效
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# MATCH (n:药品 { name: '小儿健身片' }) RETURN n.character;
# 请说明滋肾丸的禁用情况
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# MATCH (n:药品 { name: '滋肾丸' }) RETURN n.taboo;
# 哪些药品中包含天花粉？
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品) return n;
# 你能告诉我数据库里有多少种药吗？
# match (n:药品 ) return count(*);
# match (n:药品) return count(n)
# 构成香苏正胃丸的辅助成分是什么？
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# MATCH (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) RETURN m
# 请给我34条辅料的数据信息。
# match (n:辅料) return n limit 34;
# MATCH (n:辅料) RETURN n LIMIT 34;
# 国公酒的使用步骤能分享一下吗？
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# MATCH (n:药品 { name: '国公酒' }) RETURN n.useSteps;
# 数据库的节点数量是多少？
# match (n ) return count(*);
# match (n) return count(*)
# 能给我提供24条药材的数据吗?
# match (n:药材) return n limit 24;
# MATCH (n:药材) RETURN n limit 24;
# 能告诉我国公酒的使用方法吗？
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '我国公酒' }) return n.method;
# 能帮我查询一下33条药品信息吗？
# match (n:药品) return n limit 33;
# MATCH (n:药品) RETURN n limit 33;
# 请问当归补血丸的主要特性是什么？
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# 我想了解28条药品信息，能帮我查一下吗？
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# 有什么药品可以缓解腰腿疼痛？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品) return n;
# 通宣理肺丸里面主要有哪些药材？
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '通宣理肺丸' }) RETURN n.character;
# 能除湿止痛的药有哪些，你知道吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品) return n;
# 你知道通宣理肺丸是由哪些药材组成的吗？
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.taboo;
# 你知道牛黄清心丸（局方）是由哪些药材组成的吗？
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '牛黄清心丸(局方)' }) RETURN n.taboo;
# 我想获取34条中国系列的分类样本，可以吗？
# match (n:中国系列) return n limit 34;
# MATCH (n:中国系列) RETURN n limit 34;
# 能否麻烦你提供34条辅料的数据？
# match (n:辅料) return n limit 34;
# MATCH (n:辅料) RETURN n limit 34;
# 如何正确使用养阴清肺膏呢？
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.note;
# 请问数据库中收录的药材种类数量是多少？
# match (n:药材 ) return count(*);
# match (n:药材) return count(n)
# 能告诉我数据库里关系数据的条数吗？
# match (n )-[r]->(m) return count(*);
# match (n) return count(*)
# 我想知道如何正确使用橡皮生肌膏，能指导一下吗？
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# MATCH (n:药品 { name: '橡皮生肌膏' }) RETURN n.note;
# 哪些药品具有燥湿化痰的功效？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# MATCH (n:药品) RETURN n;
# 我想获取24条药材的数据，可以吗?
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# 能否提供脏连丸的全部信息？
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '脏连丸' }) return n;
# 你能告诉我耳聋通窍丸的药物类型吗?
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# MATCH (n:药品 { name: '耳聋通窍丸' }) RETURN n.type;
# 对于腰酸背痛，有什么药可以建议使用？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品)-[r:适应症]->(m:症状 {name: '腰酸背痛'} ) return n;
# 在数据库里查询一下，有多少条关系数据？
# match (n )-[r]->(m) return count(*);
# match (n) return count(n)
# 在哪些药品中可以找到栀子(姜炙)？
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '栀子(姜炙)'} ) RETURN n;
# 能否提供34种三核九翼的分类信息？
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# 小儿和胃丸里面主要有哪些药材？
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '小儿和胃丸' }) RETURN n.taboo;
# 包含哪些药品
# match (n:药品) return n;
# match (n:药品) return n;
# 请给我关于健脾养胃颗粒的全部资料
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# MATCH (n:药品 { name: '健脾养胃颗粒' }) RETURN n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 有哪些事项需要注意，如果我要使用慢惊丸？
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# 请问更年安胶囊的使用方法是什么？
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# 请问消食退热糖浆有哪些禁忌？
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# 哪些药品可以使用豆蔻(去壳)？
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return n;
# 天花粉作为原料被用于哪些药品制作？
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:原料]->(m {name: '天花粉'} ) return  n
# 能推荐一些治疗腰酸背痛的药品吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品) return n limit 10;
# 请给我32条关于药材的记录
# match (n:药材) return n limit 32;
# MATCH (n:药材) RETURN n LIMIT 32;
# 能告诉我当归补血丸都用了什么辅助材料吗？
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' }) return n辅料;
# 能告诉我小儿和胃丸的主要成分包含哪些草药吗？
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.taboo;
# 使用滋肾丸需要注意什么禁忌？
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# 能详细说一下风湿镇痛丸的药效吗？还有哪些药品有类似的效果呢？
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 三核九翼的分类有哪些细分？
# match (n:三核九翼) return n;
# MATCH (n:三核九翼) RETURN n;
# 能告诉我乌鸡白凤片怎么用吗？
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.use;
# 请给出25条辅料的信息资料
# match (n:辅料) return n limit 25;
# MATCH (n:辅料) RETURN n limit 25;
# 面对持续不断的咳嗽和百日咳，可以推荐哪些药物？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品)-[r:适应症状]->(m:症状 {name: '咳嗽' })-[r1:适应症状]->(m1:症状 {name: '百日咳' }) return n;
# 在哪些药品中发现了石决明的使用？
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品) return n;
# 能否告诉我配方里的药材有哪些？
# match (n:药材) return n;
# match (n:药品) return n;
# 哪些药品可以使用干漆(煅)？
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# MATCH (n:药品)-[r:辅料]->(m {name: '干漆(煅)'} ) RETURN n;
# 请描述一下蒲地蓝消炎片的主要作用，还有哪些药品有类似效果呢？
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' }) return n.character;
# 能告诉我朱砂安神丸怎么用吗？
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.note;
# 能告诉我更年安胶囊怎么用吗？
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.use;
# 请给我详细列出15个三核九翼的种类数据
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# 请给我提供33条药品数据
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# 请介绍一下仙茸壮阳口服液的特征和优势。
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# 耳聋通窍丸是什么类型的药物?
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# 包含哪些药材
# match (n:药材) return n;
# match (n:药材) return n;
# 什么情况下适合使用小儿健身片
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# MATCH (n:药品 { name: '小儿健身片' }) RETURN n;
# 能推荐一些治疗腰腿疼痛的药品吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# MATCH (n:药品)-[r:作用功效]->(m)  Optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# 使用豨莶片时有哪些注意事项呢？
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# 请问，通宣理肺丸的主要有效成分包含哪些？
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.taboo;
# 乳疮丸有哪些禁忌？
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# 获取name属性等于六味地黄丸的节点的id
#  match (n{name:'六味地黄丸'}) return id(n)
# MATCH (n:药品 { name: '六味地黄丸' }) RETURN id(n);
# 请问服用七珍丸需要注意什么禁忌？
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# 金匮肾气丸属于哪种类型？
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# 吴茱萸可以用在哪些药里？
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# 能给我25个配料的数据详情吗？
# match (n:辅料) return n limit 25;
# match (n:配料) return n limit 25;
# 能否推荐一些可以应对嘈杂不适的药品？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品) return n limit 10;
# 使用乳疮丸需要注意什么事项？
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.note;
# 数据库里包含多少种辅助材料？
# match (n:辅料 ) return count(*);
# match (n:辅助材料) return count(n)
# 我想查看36条药材的信息
# match (n:药材) return n limit 36;
# MATCH (n:药材) RETURN n limit 36;
# 能否提供37条关于中国系列的分类信息？
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# 能帮我查询一下20条药品信息吗？
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# 哪些药品具有除湿止痛的效果？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# MATCH (n:药品) RETURN n WHERE n.character '除湿止痛'
# 使用消炎解毒丸时有哪些禁忌事项需要注意
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# 如何正确使用更年安胶囊呢？
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# 能帮我查询一下28条药品信息吗？
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# 请问你能提供28条药品数据吗？
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# 我想了解35类三核九翼的品种信息，可以提供吗？
# match (n:三核九翼) return n limit 35;
# MATCH (n:品种) WHERE n.class = '35' RETURN n.character;
# 能否介绍一下银黄颗粒的主要作用，还有哪些药品有类似的效果呢？
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 牛黄清心丸（局方）属于哪种类型？
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# 我想获取24条中国系列的分类资料，能帮我整理一下吗？
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n limit 24;
# 我想看看24条药品的资料，能帮我查一下吗？
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# 你知道木香槟榔丸的功效吗？
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# MATCH (n:药品 { name: '木香槟榔丸' }) RETURN n.character;
# 请问一下，数据库中的关系记录有多少条？
# match (n )-[r]->(m) return count(*);
# MATCH (n) RETURN count(n)
# 请给出35条三核九翼的不同类型数据
# match (n:三核九翼) return n limit 35;
# MATCH (n:三核九翼) RETURN n limit 35;
# 能否提供25种辅料的相关数据？
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# 能否给我查询33条药品的资料？
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# 天花粉可用于哪些药物？
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '天花粉'} ) return  n
# 你知道香苏正胃丸里都有什么辅料吗？
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' }) return n.taboo;
# 你知道童宝乐片的功效吗？
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# MATCH (n:药品 { name: '童宝乐片' }) RETURN n.character;
# 告诉我蒲地蓝消炎片的功效，还有其他什么药品在这方面表现相似？
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:药品)-[r:作用功效]->(m {name: '蒲地蓝消炎片'} ) RETURN m,n;
# 请给我19条辅料的数据信息。
# match (n:辅料) return n limit 19;
# MATCH (n:辅料) RETURN n limit 19;
# 木香槟榔丸有什么作用？
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# 我想知道脏连丸的所有详情，能告诉我吗？
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '脏连丸' }) return n.character;
# 养阴清肺膏具有哪些独特的药理属性?
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# 能推荐一些舌红苔黄的药品吗?
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# MATCH (n:药品) RETURN n limit 10;
# 能告诉我十香止痛丸的辅助成分是什么吗？
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# 使用慢惊丸时需要注意什么？
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# 请问中国系列下面有哪些具体的分类？
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# 作为配菜，有什么选择？
# MATCH (n:辅料) RETURN n;
# MATCH (n:菜品) RETURN n;
# 列出一些具有燥湿化痰作用的药品。
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# MATCH (n:药品) RETURN n;
# 哪些药品可以用蔗糖？
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# MATCH (n:药品)-[r:主要成分]->(m {name: '蔗糖'} ) RETURN n;
# 你知道十香止痛丸里都有哪些辅料吗？
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# MATCH (n:药品 { name: '十香止痛丸' }) RETURN n.taboo;
# 能给我提供34条辅料的相关数据吗?
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# 你知道凉膈丸能治疗哪些症状吗？
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n.character;
# 能否提供健脾养胃颗粒的详细信息？
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 能给我提供15条辅料的详细数据吗?
# match (n:辅料) return n limit 15;
# MATCH (n:辅料) RETURN n limit 15;
# 我想知道如何正确使用乌鸡白凤片
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# MATCH (n:药品 { name: '乌鸡白凤片' }) RETURN n.note;
# 醋乳香在哪些药品中被使用？
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '醋乳香'} ) RETURN  n;
# 禁忌乳疮丸的情况有哪些？
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '禁忌乳疮丸' }) return n.specifications;
# 能否提供35种三核九翼的分类信息？
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# 能否提供36条药材的数据？
# match (n:药材) return n limit 36;
# MATCH (n:药材) return n limit 36;
# 我想了解37类三核九翼的品种信息，能提供吗？
# match (n:三核九翼) return n limit 37;
# MATCH (n:三核九翼) RETURN n;
# 覆盆子能用在哪些药里？
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# MATCH (n:药品) RETURN n;
# 能详细说一下越鞠保和丸的药效吗？还有哪些药品有类似的作用？
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' }) return n.character;
# 请说明止带片的禁用情况
# match (n:药品 { name: '止带片' }) return n.taboo;
# MATCH (n:药品 { name: '止带片' }) RETURN n.taboo;
# 能否给我展示一下15种辅料的数据情况?
# match (n:辅料) return n limit 15;
# MATCH (n:辅料) RETURN n limit 15;
# 请给我21条中国系列的分类数据实例。
# match (n:中国系列) return n limit 21;
# MATCH (n:中国系列) RETURN n limit 21;
# 豆蔻(去壳)在哪些药品中有应用？
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m:豆蔻) RETURN n;
# 请给我34份药材的资料
# match (n:药材) return n limit 34;
# MATCH (n:药材) RETURN n LIMIT 34;
# 可以告诉我药品列表吗？
# match (n:药品) return n;
# MATCH (n:药品) RETURN n;
# 能告诉我橡皮生肌膏怎么用吗？
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.note;
# 能否共享34条关于药材的信息？
# match (n:药材) return n limit 34;
# MATCH (n:药材) RETURN n limit 34;
# 我想知道在数据库中记录的辅料种类数量。
# match (n:辅料 ) return count(*);
# MATCH (n:辅料) RETURN count(n)
# 有没有推荐的药品可以治疗表寒里热？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# MATCH (n:药品) RETURN n MATCH (n)-[:作用功效]->(m) RETURN m MATCH (m)<-[r:作用功效]-(n) RETURN r;
# 在服用慢惊丸时，需要注意的事项有哪些？
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# 推荐一些能解决倦怠无力的药品吧
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# MATCH (n:药品) RETURN n limit 10;
# 能帮我查询一下24条药品信息吗？
# match (n:药品) return n limit 24;
# MATCH (n:药品) return n limit 24;
# 能否提供24条关于中国系列的分类信息？
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n limit 24;
# 中国系列有哪些细分的分类
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# 有什么药品可以推荐来缓解嘈杂不适吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品) return n;
# 请问乌鸡白凤片的服用方法是什么？
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# MATCH (n:药品 { name: '乌鸡白凤片' }) RETURN n.method;
# 能否详细描述一下小儿消食健胃丸的主要特性?
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# 能否提供37种三核九翼的分类信息数据？
# match (n:三核九翼) return n limit 37;
# MATCH (n:三核九翼) RETURN n limit 37;
# 组成的当归补血丸有哪些辅料？
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' }) return n.taboo;
# 蔗糖可以作为哪些药品的成分？
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# MATCH (n:药品)-[r:成分]->(m:化学药品) RETURN n;
# 能否提供34条关于中国系列的分类信息？
# match (n:中国系列) return n limit 34;
# MATCH (n:中国系列) RETURN n limit 34;
# 请问在三核九翼中，具体有哪些分类？
# match (n:三核九翼) return n;
# MATCH (n:三核九翼) RETURN n;
# 请给我详细列出16个三核九翼的种类数据
# match (n:三核九翼) return n limit 16;
# MATCH (n:三核九翼) RETURN n;
# 你能查到数据库中有多少种类的药材吗？
# match (n:药材 ) return count(*);
# match (n:药材) return count(n)
# 请给我36条关于药材的记录
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# 你能告诉我数据库中有多少种不同的辅料吗？
# match (n:辅料 ) return count(*);
# MATCH (n:辅料) RETURN COUNT(DISTINCT n);
# 能否详细说明一下仙茸壮阳口服液的药理特性？
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# 蕲蛇(酒炙)常用于哪些药物中
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) RETURN  r;
# 请给我20份药材的数据资料。
# match (n:药材) return n limit 20;
# MATCH (n:药材) RETURN n limit 20;
# 听说童宝乐片效果不错，能告诉我具体些吗？
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 能否帮我查一下21条药品的资料？
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# 请问金匮肾气丸是哪一类药物？
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# MATCH (n:药品 { name: '金匮肾气丸' }) RETURN n category;
# 你能告诉我豨莶片要注意什么吗？
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# 请问包含哪些药材？
# match (n:药材) return n;
# MATCH (n:药材) RETURN n;
# 请问耳聋通窍丸属于哪种药物类别?
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.character;
# 能否提供一些关于当归补血丸的特性描述？
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# 在服用豨莶片时需要注意什么事项？
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# 请给我15条辅料的相关数据信息
# match (n:辅料) return n limit 15;
# MATCH (n:辅料) RETURN n limit 15;
# 请给出37条三核九翼的不同种类数据
# match (n:三核九翼) return n limit 37;
# MATCH (n:三核九翼) RETURN n LIMIT 37;
# 哪些药品可以使用黄柏(盐炒)
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '黄柏(盐炒)' }) RETURN n;
# 能帮我查询一下21条药品信息吗？
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# 这里面的药物成分有哪些？
# match (n:药品) return n;
# MATCH (n:药品) RETURN n;
# 能告诉我金匮肾气丸的类别吗？
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.character;
# 我想了解银黄颗粒的药效，同时，还有没有其他药品具有类似的作用？
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m) RETURN m;
# 国公酒里的主要药材成分是什么？
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '国公酒' }) RETURN n.taboo;
# 能否详细描述一下养阴清肺膏的特性?
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# 请问一下橡皮生肌膏的使用步骤是什么？
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# 使用舟车丸需要注意什么？
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.note;
# 请问有什么药品可以解决表寒里热的问题？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品) return n;
# 你知道哪些药品可以燥湿化痰吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品) return n;
# 在哪些药品的配方中包含了干漆(煅)？
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# MATCH (n:药品)-[r:配方]-(m:药品 { name: '干漆(煅)' }) RETURN n;
# 在哪些药品中可以发现蕲蛇(酒炙)作为成分
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) RETURN n;
# 能给我提供37种辅料的数据吗?
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# 温中散寒的药物包括哪些种类？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品)-[r:作用功效]->(m:功效作用 { name: '温中散寒' }) return n;
# 清胃黄连片的包装是什么样的？
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# 我想查看32条药材的信息，可以吗？
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# 我想看看关于20条药品的资料，能帮我查一下吗？
# match (n:药品) return n limit 20;
# MATCH (n:药品) return n limit 20;
# 请给我24条中国系列的分类数据，可以吗？
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n limit 24;
# 对于表寒里热，您能推荐一些药品吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# MATCH (n:药品) RETURN n limit 10;
# 栀子(姜炙)是哪些药物的成分？
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '栀子(姜炙)'}) return  n
# 有什么药品可以缓解倦怠无力？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# MATCH (n:药品) RETURN n;
# 干漆(煅)常用于哪些药物中？
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '干漆(煅)'} ) return n
# 能否告诉我清胃黄连片的包装信息？
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# 能告诉我数据库包含的节点数吗？
# match (n ) return count(*);
# match (n) return count(*)
# 十香止痛丸里加了什么辅料？
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# 能否提供八宝坤顺丸的主要特性?
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# 木香槟榔丸的药效体现在哪些方面？
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# 哪些药品具有消炎退热的作用？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# MATCH (n:药品) RETURN n;
# 请问牛黄清心丸（局方）的分类是什么？
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.specifications;
# 滋肾丸有哪些禁忌事项？
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# 列举一些具有化痰除湿效果的药物
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品) return n.character;
# 小儿健身片适用什么症状
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# MATCH (n:药品 { name: '小儿健身片' }) RETURN n symptom;
# 你知道哪些药物能消炎退热吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品) return n;
# 我想了解小儿消食健胃丸的特性和适用情况
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# MATCH (n:药品 { name: '小儿消食健胃丸' }) RETURN n.character;
# 请问如何使用国公酒？
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n;
# 请问你能提供24条药品数据吗？
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# 能告诉我消食退热糖浆的禁用情况吗？
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# 有什么药品可以缓解腰酸背痛？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品) return n;
# 对于腰腿疼痛，有什么药品可以建议使用吗？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# MATCH (n:药品) WHERE n.name = '腰腿疼痛' RETURN n;
# 你能告诉我牛黄清心丸（局方）的所属类别吗？
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# MATCH (n:药品 { name: '牛黄清心丸（局方）' }) RETURN n.character;
# 我想了解34类三核九翼的品种信息，能给我吗？
# match (n:三核九翼) return n limit 34;
# match (n:品种)-[:三核九翼]->(m {class: '34'}) return m;
# 请问能否给我24条关于药材的详细信息?
# match (n:药材) return n limit 24;
# MATCH (n:药材) RETURN n limit 24;
# 止带片有哪些使用禁忌呢
# match (n:药品 { name: '止带片' }) return n.taboo;
# MATCH (n:药品 { name: '止带片' }) RETURN n.taboo;
# 使用覆盆子的药品种类有哪些？
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# MATCH (n:药品)-[r:作用功效]->(m:覆盆子) RETURN n;
# 黄柏(盐炒)常用于哪些药物中
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# 能给我提供19条辅料的相关数据吗?
# match (n:辅料) return n limit 19;
# MATCH (n:辅料) RETURN n limit 19;
# 对于舌红苔黄，有什么药品可以建议?
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# MATCH (n:药品) WHERE n.character === '舌红苔黄' RETURN n;
# 七珍丸有哪些使用禁忌呢？
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# MATCH (n:药品 { name: '七珍丸' }) RETURN n.taboo;
# 能否提供16种三核九翼的分类信息？
# match (n:三核九翼) return n limit 16;
# MATCH (n:三核九翼) RETURN n;
# 请介绍一下八宝坤顺丸的特征和优势。
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# 哪些药品可以使用醋乳香？
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '醋乳香'} ) return n;
# 牛黄清心丸（局方）里面主要有哪些药材？
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 {name: '牛黄清心丸（局方）'} ) return n.character;
# 能否给我一份包含37条辅料信息的数据?
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# 我想了解朱砂安神丸的使用指导
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# MATCH (n:药品 { name: '朱砂安神丸' }) RETURN n.useMethod;
# 能给我提供34条药材的数据吗?
# match (n:药材) return n limit 34;
# MATCH (n:药材) RETURN n LIMIT 34;
# 你知道吴茱萸可以作为哪些药品的成分吗？
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# MATCH (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) RETURN  n
# 凉膈丸适用什么症状？
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n symptom;
# 请问桑菊感冒颗粒的主要有效成分包含哪些草药？
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.character;
# 请给我34条中国系列的分类数据实例。
# match (n:中国系列) return n limit 34;
# MATCH (n:中国系列) RETURN n limit 34;
# 我想获取37条中国系列的分类样本，可以吗？
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# 能否介绍一下越鞠保和丸的功效？类似效果的药品还有哪些呢？
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' }) return n.character;
# 有哪些东西可以作为辅料
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# 能化痰除湿的药有哪些？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# MATCH (n:药品) RETURN n;
# 我想了解一下中国系列的分类，能给我17条数据吗？
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# 我想了解健脾养胃颗粒的所有信息，可以告诉我吗？
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# 上清丸有哪些禁忌事项？
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# 请说明上清丸的禁用情况
# match (n:药品 { name: '上清丸' }) return n.taboo;
# MATCH (n:药品 { name: '上清丸' }) RETURN n.taboo;
# 能否麻烦你分享一下19条辅料的数据？
# match (n:辅料) return n limit 19;
# MATCH (n:辅料) RETURN n LIMIT 19;
# 请给我提供20条药品数据
# match (n:药品) return n limit 20;
# MATCH (n:药品) RETURN n limit 20;
# 在哪些药方中醋乳香是必需的？
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '醋乳香'}) RETURN n;
# 我想了解16种三核九翼的类型信息，可以提供吗？
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# 能详细说说三核九翼的细分分类吗？
# match (n:三核九翼) return n;
# MATCH (n:三核九翼) RETURN n;
# 数据库里总共有多少药品？
# match (n:药品 ) return count(*);
# match (n:药品) return count(n)
# 哪些药品可以使用蕲蛇(酒炙)
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# MATCH (n:药品)-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) RETURN n;
# 查询一下，数据库中存储的药品种类数量
# match (n:药品 ) return count(*);
# MATCH (n:药品) RETURN count(n)
# 请给我37条中国系列的分类数据实例。
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# 能告诉我热毒平颗粒怎么用吗？
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# 请问热毒平颗粒的用药方法是什么？
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.taboo;
# 禁忌服用舟车丸的情况有哪些？
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# 中国系列可以细分为哪些分类？
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# 在哪些药品中可以找到蔗糖作为原料？
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品)-[r:原料]->(m {name: '蔗糖'}) return n;
# 你知道桑菊感冒颗粒是由哪些药材组成的吗？
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '桑菊感冒颗粒' }) RETURN n.taboo;
# 能否介绍一下蒲地蓝消炎片的药效？并给出其他具有类似效果的药品名字。
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' }) return n.character;
# 请问养阴清肺膏的使用步骤是什么？
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# 你知道哪些药品可以化痰除湿吗？
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# MATCH (n:药品) RETURN n;
# 改写句子
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嗳气胀满' }) return   n ;
# match (n) return n;
# 使用止带片需要注意什么事项
# match (n:药品 { name: '止带片' }) return n.taboo;
# MATCH (n:药品 { name: '止带片' }) RETURN n.note;
# 童宝乐片有什么作用？
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# 香苏正胃丸的辅料有哪些？
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# MATCH (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) RETURN m;
# 请问，制作牛黄清心丸（局方）需要用到哪些主要药材？
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸' }) return n.character;
# 对于哪些症状，凉膈丸是适用的？
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# MATCH (n:药品)-[r:适应症状]->(m)  RETURN  m
# 当归补血丸里添加了什么辅助成分？
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# 能否提供32条药材的数据？
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# 请问国公酒的主要药材成分包含哪些？
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.taboo;
# 你知道数据库有多少个节点吗？
# match (n ) return count(*);
# MATCH (n) RETURN count(*)
# 桑菊感冒颗粒里面主要有哪些药材？
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# MATCH (n:药品 { name: '桑菊感冒颗粒' }) RETURN n.character;
# 能否提供15种三核九翼的分类信息？
# match (n:三核九翼) return n limit 15;
# MATCH (n:三核九翼) RETURN n limit 15;
# 请问朱砂安神丸的用药方法是什么？
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.method;
# 请给我17条中国分类数据的例子。
# match (n:中国系列) return n limit 17;
# match (n:中国分类) return n limit 17;
# 如何使用热毒平颗粒？请指导一下
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.note;
# 针对舌红苔黄的症状，有哪些药品推荐?
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:药品)-[r:症状]->(m:症状 { name: '舌红苔黄' }) return n;
# 哪些药品中可以添加覆盆子？
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品)-[r:辅料]->(m)<-[r1:辅料]-(m1) return m,m1;
# 请提供小儿消食健胃丸的特性信息和功效
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# MATCH (n:药品 { name: '小儿消食健胃丸' }) RETURN n.character;
# 石决明可用于哪些药物？
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '石决明'} ) return  n
# 请问有什么药品可以应对倦怠无力的情况？
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品) return n;

# %%
## my prompt
import json
key_values1 = None
no_prompt_notrain_val = []
with open("/data/liuytest/数据处理/中医药/train_data_my_prompt_test.json", 'r',encoding="utf-8") as json_file:
    key_values1 = json.load(json_file)
    for kv in key_values1:
        # print(kv['instruction'])
        print(kv['output'])
        data['messages'][0]['content'] = kv['instruction']

        response = requests.post(url, json=data, timeout=600)
        json_data = response.json()
        # print(json_data)
        json_data =  json_data["choices"][0]["message"]["content"]
        print(json_data)
        no_prompt_notrain_val.append({"label":kv['output'],"predict":json_data})

with open(f"zyy_train_data_my_prompt_train_test_{model}.json", 'w',encoding="utf-8") as json_file:
    json.dump(no_prompt_notrain_val, json_file ,ensure_ascii=False,indent=4)
# Out:
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '温中散寒'} ) return  n
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '除湿止痛'} ) return  n
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:症状 { name: '嘈杂不适' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.main_component;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m:功能 { name: '温中散寒' }) return  n
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '持久的咳嗽和百日咳'} ) return  n
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明(煅)' }) return  n
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '久嗽不已及百日咳'} ) return  n
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m: 药材 ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 { name: '豆蔻(去壳)' }) return n.character;
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:药材 ) return count(*);
# match (n:药品) return count(*)
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {taboo: '消炎退热' }) return  m
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m)  return  m
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 ) return count(*);
# match (n:药品) return count(*)
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n.useMethod;
# match (n ) return count(*);
# match (n) return count(*)
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n.useMethod;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状  [name='腰腿疼痛']) return  n
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.character;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 { name: '化湿止痛' }) return n;
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.mainComponent;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.mainComponent;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药材 ) return count(*);
# match (n:药材) return count(*)
# match (n )-[r]->(m) return count(*);
# match (n) return count(*)
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '燥湿化痰'} ) return  n
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品 { name: '腰酸背痛' }) return n.name;
# match (n )-[r]->(m) return count(*);
# match (n) return count(n)
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品)-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品  { name: '腰酸背痛' }) return n;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m)  return  m
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.character;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 { name: '复方百部止咳糖浆' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明(煅)' }) return  n
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m: 药材 ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.specifications;
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品  { name: '耳聋通窍丸' }) return n.type;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 { name: '腰疼腿疼' }) return  n
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.character;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '嘈杂不适'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.note;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(n)
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '除湿止痛'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼 ) return n limit 35;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n )-[r]->(m) return count(*);
# match (n) return count(*)
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:药品 { name: '舌红苔黄' }) return n;
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 { character: '燥湿化痰' }) return n;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:辅料成分]->(m:辅料 {name: '蔗糖'} ) return  n
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return  m
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m)  return m
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼 ) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.specifications;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(n);
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m :症状 {name: '表寒里热'} ) return  n
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 { name: '倦怠无力' }) return  n
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '嘈杂不适'} ) return  n
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 3;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '蔗糖'} ) return  n
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:药材 ) return count(*);
# match (n:药材) return count(*)
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*)
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 { name: '蕲蛇(酒炙)' })-[r:主要成分]->(m)  return  m
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.note;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 { name: '黄柏(盐炒)' }) return n;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品) return n;
# match (n:药品 )-[r:主要成分]->(m) return  m
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.mainComponent;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 { name: '表寒里热' }) return  n
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '燥湿化痰'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)' }) return  n
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m { name: '温中散寒' }) return  n
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:症状 { name: '表寒里热' })-[r:适应症状]->(m)  optional match  (m)<-[r2:适应症状]-(m1) return m,m1;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:name {name: '倦怠无力'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 { name: '干漆(煅)' })-[r:主要成分]->(m)  return  m
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n ) return count(*);
# match (n) return count(n);
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m )  return  m
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m { name: '化痰除湿' }) return  m
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n适应症状;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m )  return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品  { name: '国公酒' }) return n.name;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:name { name: '腰酸背痛' }) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 { name: '腰腿疼痛' }) return  n
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品  { name: '覆盆子' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:药品 { name: '舌红苔黄' }) return n;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n适应症状;
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '化痰除湿'} ) return  n
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '乳香(醋制)' }) return  n
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 ) return count(*);
# match (n:药品) return count(n);
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)' }) return  n
# match (n:药品 ) return count(*);
# match (n:药品) return count(n)
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:辅料成分]->(m:辅料 {name: '蔗糖'} ) return  n
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.mainComponent;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '化痰除湿'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嗳气胀满' }) return   n ;
# match (n:药品 ) return n;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.note;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m:症状 ) return  m
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.main_component;
# match (n ) return count(*);
# match (n) return count(n);
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' })-[r:主要成分]->(m: 药材 ) return  m
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' })-[r:适应症状]->(m:药品 ) return  m
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明(煅)' }) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:name {name: '倦怠无力'} ) return  n

# %%
## schema prompt
import json
key_values1 = None
no_prompt_notrain_val = []
with open("/data/liuytest/数据处理/中医药/train_data_schema_prompt_test.json", 'r',encoding="utf-8") as json_file:
    key_values1 = json.load(json_file)
    for kv in key_values1:
        # print(kv['instruction'])
        print(kv['output'])
        data['messages'][0]['content'] = kv['instruction']

        response = requests.post(url, json=data, timeout=600)
        json_data = response.json()
        # print(json_data)
        json_data =  json_data["choices"][0]["message"]["content"]
        print(json_data)
        no_prompt_notrain_val.append({"label":kv['output'],"predict":json_data})

with open(f"zyy_train_data_schema_prompt_train_test_{model}.json", 'w',encoding="utf-8") as json_file:
    json.dump(no_prompt_notrain_val, json_file ,ensure_ascii=False,indent=4)
# Out:
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '温中散寒'} ) return  n
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '除湿止痛'}) return  m
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.mainComponent;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '嘈杂不适'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.main_component;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.specifications;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '能温中散寒'} ) return  n
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '咳嗽' })-[r2:适应症状]->(m1 {name: '百日咳'}) return  n
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '长期咳嗽和百日咳'} ) return  n
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '牛黄'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 { name: '豆蔻(去壳)' }) return n.character;
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 { name: '栀子(姜炙)' }) return n;
# match (n:药材 ) return count(*);
# match (n:药品) return count(*)
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '消炎退热'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n适应症状;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 ) return count(*);
# match (n:药品) return count(*)
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n.useMethod;
# match (n ) return count(*);
# match (n ) return count(*)
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '我国公酒' }) return n.useMethod;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '腰腿疼痛'} ) return  n
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.main_component;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 { name: '健脾除湿丸' })-[r:作用功效]->(m)  return m
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.mainComponent;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸' }) return n.mainComponent;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药材 ) return count(*);
# match (n:药材) return count(n);
# match (n )-[r]->(m) return count(*);
# match (n:关系) return count(n);
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.note;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '燥湿化痰'} ) return  n
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:症状 { name: '腰酸背痛' })-[r:适应症状]->(m:药品 ) return  m
# match (n )-[r]->(m) return count(*);
# match (n) return count(n)
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.main_component;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '腰酸背痛'} ) return  n
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.main_component;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '咳嗽' })-[r2:适应症状]->(m1 {name: '百日咳'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '腰腿疼痛'} ) return  n
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.mainComponent;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '嘈杂不适'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.note;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*)
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '除湿止痛'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n )-[r]->(m) return count(*);
# match (n:关系) return count(*)
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '舌红苔黄'} ) return  n
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '燥湿化痰'} ) return  n
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '蔗糖'} ) return  n
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m)  return m
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '禁忌乳疮丸' }) return n.taboo;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼 ) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(n);
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '表寒里热'} ) return  n
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m {name: '倦怠无力'} ) return  n
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 { name: '嘈杂不适' }) return  n
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.useMethod;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 37;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return  m
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '蔗糖'} ) return  n
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:药材 ) return count(*);
# match (n:药材) return count(*)
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*)
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 { name: '蕲蛇(酒炙)' })-[r:主要成分]->(m)  return m
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.taboo;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.category;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 { name: '黄柏(盐炒)' }) return n;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品) return n;
# match (n:药品 )-[r:主要成分]->(m) return  m
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.category;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.main_component;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '表寒里热'} ) return  n
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '半夏'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:分类]->(m {name: '温中散寒'} ) return  n
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 { name: '寒里热' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 { name: '栀子(姜炙)' })-[r:主要成分]->(m) return m;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '倦怠无力'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n ) return count(*);
# match (n ) return count(n ) ;
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n辅料;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '消炎退热'} ) return  n
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.category;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '化痰除湿'} ) return  n
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n适应症状;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '消炎退热'} ) return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品  { name: '国公酒' }) return n ;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '腰酸背痛'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m { name: '腰腿疼痛' }) return  n
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.type;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品  { name: '覆盆子' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' }) return n.name;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.main_component;
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.note;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n适应症状;
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.character;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:辅料) RETURN n;
# MATCH (n:辅料) RETURN n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '化痰除湿'} ) return  m
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 ) return count(*);
# match (n:药品) return count(n);
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 { name: '蕲蛇(酒炙)' }) return n;
# match (n:药品 ) return count(*);
# match (n:药品) return count(n);
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '蔗糖'} ) return  n
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.main_component;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:主要成分]->(m {name: '化痰除湿'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嗳气胀满' }) return   n ;
# match (n:药品 ) return n;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.note;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' }) return n辅料;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:主要成分]->(m { }) return  m
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m:症状 ) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.mainComponent;
# match (n ) return count(*);
# match (n ) return count(*) ;
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.mainComponent;
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' })-[r:适应症状]->(m:药品 ) return m
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m:症状 {name: '倦怠无力'} ) return  n

# %%
## vector prompt
import json
key_values1 = None
no_prompt_notrain_val = []
with open("/data/liuytest/数据处理/中医药/train_data_vector_prompt_test.json", 'r',encoding="utf-8") as json_file:
    key_values1 = json.load(json_file)
    for kv in key_values1:
        # print(kv['instruction'])
        print(kv['output'])
        data['messages'][0]['content'] = kv['instruction']

        response = requests.post(url, json=data, timeout=600)
        json_data = response.json()
        # print(json_data)
        json_data =  json_data["choices"][0]["message"]["content"]
        print(json_data)
        no_prompt_notrain_val.append({"label":kv['output'],"predict":json_data})

with open(f"zyy_train_data_vector_prompt_train_test_{model}.json", 'w',encoding="utf-8") as json_file:
    json.dump(no_prompt_notrain_val, json_file ,ensure_ascii=False,indent=4)
# Out:
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品)-[r:作用功效]->(m {name: '温中散寒'} ) return  n
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name:'除湿止痛'} ) return  n
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.taboo;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '嘈杂不适'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.taboo;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.note;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药品 )-[r:功能]->(m {name : '温中散寒'} ) return  n
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品)-[r:适应症]->(m {name: '咳嗽和百日咳'} ) return  n
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品 )-[r:适应症]->(m {name: '长期咳嗽和百日咳'} ) return  n
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '巴戟天'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:药材 ) return count(*);
# match (n:药品) return count(*)
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品)-[r:作用功效]->(m {name: '消炎退热'}) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.id;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n.specifications;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 ) return count(*);
# match (n:药品) return count(*);
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n.taboo;
# match (n ) return count(*);
# match (n) return count(*) as x;  x
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品 { name: '国公酒' }) return n.useMethod;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '腰腿疼痛'} ) return  n
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.taboo;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品  { name: '除湿止痛' }) return n;
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.taboo;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸(局方)' }) return n.taboo;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.note;
# match (n:药材 ) return count(*);
# match (n:药材) return count(*);
# match (n )-[r]->(m) return count(*);
# match (n) return count(*);
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.note;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:主要功效]->(m {name: '燥湿化痰'} ) return  n
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.character;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:症状 { name: '腰酸背痛' })-[r:建议用药]->(m:药品 ) return m;
# match (n )-[r]->(m) return count(*);
# match (n) return count(*);
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼) return n limit 34;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.specifications;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.useMethod;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m {name: '腰酸背痛'} ) return  n
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' }) return n.specifications;
# match (n:药品 {name: '小儿和胃丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '小儿和胃丸' }) return n.character;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '风湿镇痛丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.taboo;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '久嗽不已及百日咳' }) return   n ;
# match (n:药品)-[r:适应症状]->(m {name: '咳嗽和百日咳'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药材) return n;
# match (n:药品 )-[r:主要成分]->(m)  return  m
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.taboo;
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.type;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m { name : '腰腿疼痛' }) return  n
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 {name: '通宣理肺丸'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '通宣理肺丸' }) return n.character;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
#  match (n{name:'六味地黄丸'}) return id(n)
# match (n:药品  { name: '六味地黄丸' }) return n.character;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '嘈杂不适'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.note;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*);
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '除湿止痛' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name:'除湿止痛'} ) return  n
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品 { name: '消炎解毒丸' }) return n.taboo;
# match (n:药品  { name: '更年安胶囊' }) return  n.useMethod ;
# match (n:药品 { name: '更年安胶囊' }) return n.note;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:药品) return n limit 28;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼 { class: '35' }) return n;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品  { name: '牛黄清心丸（局方）' }) return n.character;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n )-[r]->(m) return count(*);
# match (n) return count(*);
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return n limit 35;
# match (n:辅料) return n limit 25;
# match (n:辅料) return n limit 25;
# match (n:药品) return n limit 33;
# match (n:药品) return n limit 33;
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '天花粉'} ) return  n
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' }) return n.specifications;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '脏连丸' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' }) return n.name,n.note,n.taboo,n.specifications,n.package,n.useMethod;
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n.specifications;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '燥湿化痰'} ) return  n
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:辅料]->(m {name: '蔗糖'} ) return  n
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n.specifications;
# match (n:辅料) return n limit 34;
# match (n:辅料) return n limit 34;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n.character;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.note;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:药品 { name: '乳疮丸' }) return n.taboo;
# match (n:三核九翼) return n limit 35;
# match (n:三核九翼) return count(*);
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼 { class: '37' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:中国系列) return n limit 21;
# match (n:中国系列) return n limit 21;
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '豆蔻(去壳)' }) return  n
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品) return n;
# match (n:药品) return n;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.note;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*);
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m {name: '表寒里热'} ) return  n
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品 { name: '慢惊丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m {name: '倦怠无力'} ) return  n
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# MATCH (n:中国系列) RETURN n;
# MATCH (n:中国系列) RETURN n;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嘈杂不适' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {适应症状: '嘈杂不适'} ) return  n
# match (n:药品  { name: '乌鸡白凤片' }) return  n.useMethod ;
# match (n:药品 { name: '乌鸡白凤片' }) return n.taboo;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 37;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '蔗糖'} ) return  n
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:药材 ) return count(*);
# match (n:药材) return count(*)
# match (n:药材) return n limit 36;
# match (n:药材) return n limit 36;
# match (n:辅料 ) return count(*);
# match (n:辅料) return count(*);
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 { name: '仙茸壮阳口服液' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)' }) return  n
# match (n:药材) return n limit 20;
# match (n:药材) return n limit 20;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.type;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药材) return n;
# match (n:药材) return n;
# match (n:药品 { name: '耳聋通窍丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '耳聋通窍丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '当归补血丸' }) return n.character;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:药品 { name: '豨莶片' }) return n.note;
# match (n:辅料) return n limit 15;
# match (n:辅料) return n limit 15;
# match (n:三核九翼) return n limit 37;
# match (n:三核九翼) return n limit 37;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:药品) return n limit 21;
# match (n:药品) return n limit 21;
# match (n:药品) return n;
# match (n:药品 )-[r:主要成分]->(m) return  m
# match (n:药品 { name: '金匮肾气丸' })-[r:分类]->(m) return m;
# match (n:药品 { name: '金匮肾气丸' }) return n.character;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '银黄颗粒' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品 { name: '养阴清肺膏' }) return n.character;
# match (n:药品  { name: '橡皮生肌膏' }) return  n.useMethod ;
# match (n:药品 { name: '橡皮生肌膏' }) return n.useMethod;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:药品)-[r:功能]->(m {name: '表寒里热'} ) return  n
# match (n:药品)-[r:作用功效]->(m :功能 { name : '燥湿化痰' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name:'燥湿化痰'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)' }) return  n
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '温中散寒' }) return  n ;
# match (n:药物作用 )-[r:作用功效]->(m {name: '温中散寒'} ) return  m
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:中国系列) return n limit 24;
# match (n:中国系列) return n limit 24;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '表寒里热' }) return   n ;
# match (n:症状 { name: '表寒里热' })-[r:治疗药品]->(m) return m;
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '栀子(姜炙)' }) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '倦怠无力'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '干漆(煅)' }) return  n
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n:药品 { name: '清胃黄连片' }) return n.specifications;
# match (n ) return count(*);
# match (n) return count(*);
# match (n:药品 { name: '十香止痛丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '十香止痛丸' }) return n.specifications;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '木香槟榔丸' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '木香槟榔丸' }) return n.character;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name:'消炎退热'} ) return  n
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.specifications;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品 { name: '滋肾丸' }) return n.taboo;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '化痰除湿'} ) return  n
# match (n:药品 { name: '小儿健身片' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '小儿健身片' }) return n.character;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '消炎退热' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '退热消炎'} ) return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品  { name: '国公酒' }) return  n.useMethod ;
# match (n:药品  { name: '国公酒' }) return n.taboo;
# match (n:药品) return n limit 24;
# match (n:药品) return n limit 24;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品 { name: '消食退热糖浆' }) return n.taboo;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰酸背痛' }) return   n ;
# match (n:药品)-[r:适应症状]->(m { symptom: '腰酸背痛' }) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '腰腿疼痛' }) return   n ;
# match (n:药品 )-[r:适应症状]->(m {name: '腰腿疼痛'} ) return  n
# match (n:药品 { name: '牛黄清心丸（局方）' })-[r:分类]->(m) return m;
# match (n:药品  { name: '牛黄清心丸（局方）' }) return n.character;
# match (n:三核九翼) return n limit 34;
# match (n:三核九翼 { name: '34' }) return n.character;
# match (n:药材) return n limit 24;
# match (n:药材) return n limit 24;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品  { name: '覆盆子' }) return n;
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '黄柏(盐炒)' }) return  n
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' }) return n.name,n.note,n.taboo,n.treatMethod;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:药品 { name: '七珍丸' }) return n.taboo;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 { name: '八宝坤顺丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:药品 )-[r:主要辅料]->(m {name: '醋乳香'} ) return  n
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.specifications;
# match (n:辅料) return n limit 37;
# match (n:辅料) return n limit 37;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.useMethod;
# match (n:药材) return n limit 34;
# match (n:药材) return n limit 34;
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '吴茱萸'} ) return  n
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' }) return n.character;
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.character;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 34;
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '越鞠保和丸' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# MATCH (n:辅料) RETURN n;
# match (n:辅料) return n;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '化痰除湿'} ) return  n
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品  { name: '健脾养胃颗粒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:药品 { name: '上清丸' }) return n.taboo;
# match (n:辅料) return n limit 19;
# match (n:辅料) return n limit 19;
# match (n:药品) return n limit 20;
# match (n:药品) return n limit 20;
# match (n:药品 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:方剂 )-[r:主要成分]->(m {name: '醋乳香'} ) return  n
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n limit 16;
# match (n:三核九翼) return n;
# match (n:三核九翼) return n;
# match (n:药品 ) return count(*);
# match (n:药品) return count(*);
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '蕲蛇(酒炙)' }) return  n
# match (n:药品 ) return count(*);
# match (n:药品) return count(*);
# match (n:中国系列) return n limit 37;
# match (n:中国系列) return n limit 37;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.useMethod;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# match (n:药品 { name: '舟车丸' }) return n.taboo;
# MATCH (n:中国系列) RETURN n;
# match (n:中国系列) return n;
# match (n:药品)-[r:辅料成分]->(m :辅料 { name : '蔗糖' }) return n;
# match (n:药品 )-[r:主要原料]->(m {name: '蔗糖'} ) return  n
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.taboo;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品 { name: '蒲地蓝消炎片' })-[r:作用功效]->(m)  optional match  (m)<-[r2:作用功效]-(m1) return m,m1;
# match (n:药品  { name: '养阴清肺膏' }) return  n.useMethod ;
# match (n:药品 { name: '养阴清肺膏' }) return n.useMethod;
# match (n:药品)-[r:作用功效]->(m :功能 { name : '化痰除湿' }) return  n ;
# match (n:药品 )-[r:作用功效]->(m {name: '化痰除湿'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '嗳气胀满' }) return   n ;
# match (n) return n;
# match (n:药品 { name: '止带片' }) return n.taboo;
# match (n:药品 { name: '止带片' }) return n.note;
# match (n:药品 { name: '童宝乐片' })-[r:作用功效]->(m) return m;
# match (n:药品 { name: '童宝乐片' }) return n.character;
# match (n:药品 { name: '香苏正胃丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '香苏正胃丸' }) return n.specifications;
# match (n:药品 {name: '牛黄清心丸（局方）'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '牛黄清心丸（局方）' }) return n.specifications;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '凉膈丸' })-[r:适应症状]->(m) return m;
# match (n:药品 { name: '当归补血丸' })-[r:辅料]->(m) return m;
# match (n:药品 { name: '当归补血丸' }) return n.taboo;
# match (n:药材) return n limit 32;
# match (n:药材) return n limit 32;
# match (n:药品 {name: '国公酒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '国公酒' }) return n.name,n.package,n.note,n.specifications,n.taboo,n.useMethod;
# match (n ) return count(*);
# call db.schema.nodeTypeCount();
# match (n:药品 {name: '桑菊感冒颗粒'} )-[r:主要成分]->(m: 药材 ) return  m
# match (n:药品 { name: '桑菊感冒颗粒' }) return n.taboo;
# match (n:三核九翼) return n limit 15;
# match (n:三核九翼) return n limit 15;
# match (n:药品  { name: '朱砂安神丸' }) return  n.useMethod ;
# match (n:药品 { name: '朱砂安神丸' }) return n.taboo;
# match (n:中国系列) return n limit 17;
# match (n:中国系列) return n limit 17;
# match (n:药品  { name: '热毒平颗粒' }) return  n.useMethod ;
# match (n:药品 { name: '热毒平颗粒' }) return n.note;
# match (n:药品)-[r:适应症状]->(m :症状 { name : '舌红苔黄' }) return   n ;
# match (n:症状 { name: '舌红苔黄' })-[r:治疗药品]->(m) return m;
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '覆盆子'} ) return  n
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 { name: '小儿消食健胃丸' }) return n.character;
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品 )-[r:主要成分]->(m {name: '石决明'} ) return  n
# match (n:药品)-[r:适应症状]->(m :症状 { name : '倦怠无力' }) return   n ;
# match (n:药品 )-[r:作用功效]->(m {name: '倦怠无力'} ) return  n
